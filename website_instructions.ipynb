# %% [markdown]
# 1. At first log in to the account.
#
# 2. Then, goto https://github.com/eliahuhorwitz/Academic-project-page-template. And click the button "Use this template".
#
# 3. The, give the name and choose the visibility. If we want to make it private then, we cannot get any domain link.
#
# (we will see later how to make it public and get the link).
#
# 4. Then, git clone the new repository I have made. Then, open the `index.html` file and start editing. We can open this index.html file
#
#    in the browser with RMB this file and open with browser so observe the changes.
